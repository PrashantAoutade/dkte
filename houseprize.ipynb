# %% [markdown]
# <a href="https://colab.research.google.com/github/PrashantAoutade/dkte/blob/master/houseprize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
model = keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs=np.array([1,2,3,4,5,6,7], dtype=int)
ys=np.array([50,100,150,200,250,300,350], dtype=int)

# %%
model.fit(xs,ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 1ms/step - loss: 52074.3398
# Epoch 2/500
# 1/1 [==============================] - 0s 1ms/step - loss: 17763.5996
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 6067.8384
# Epoch 4/500
# 1/1 [==============================] - 0s 1ms/step - loss: 2080.9536
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 721.8288
# Epoch 6/500
# 1/1 [==============================] - 0s 1ms/step - loss: 258.4413
# Epoch 7/500
# 1/1 [==============================] - 0s 1ms/step - loss: 100.3895
# Epoch 8/500
# 1/1 [==============================] - 0s 1ms/step - loss: 46.4192
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 27.9285
# Epoch 10/500
# 1/1 [==============================] - 0s 3ms/step - loss: 21.5326
# Epoch 11/500
# 1/1 [==============================] - 0s 1ms/step - loss: 19.2602
# Epoch 12/500
# ...

# %%
print(model.predict([8]))
# Out:
# [[399.11197]]
